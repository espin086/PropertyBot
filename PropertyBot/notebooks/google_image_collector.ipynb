# %%
from bs4 import BeautifulSoup
import requests
import re
import urllib2
import os
import cookielib
import json

def get_soup(url,header):
    return BeautifulSoup(urllib2.urlopen(urllib2.Request(url,headers=header)),'html.parser')


query = raw_input("query image")# you can change the query for the image  here
image_type="ActiOn"
query= query.split()
query='+'.join(query)
url="https://www.google.co.in/search?q="+query+"&source=lnms&tbm=isch"
print url
#add the directory for your image here
DIR="Pictures"
header={'User-Agent':"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/43.0.2357.134 Safari/537.36"
}
soup = get_soup(url,header)


ActualImages=[]# contains the link for Large original images, type of  image
for a in soup.find_all("div",{"class":"rg_meta"}):
    link , Type =json.loads(a.text)["ou"]  ,json.loads(a.text)["ity"]
    ActualImages.append((link,Type))

print  "there are total" , len(ActualImages),"images"
if not os.path.exists(DIR):
            os.mkdir(DIR)
DIR = os.path.join(DIR, query.split()[0])

if not os.path.exists(DIR):
            os.mkdir(DIR)
###print images
for i , (img , Type) in enumerate( ActualImages):
    try:
        req = urllib2.Request(img, headers={'User-Agent' : header})
        raw_img = urllib2.urlopen(req).read()

        cntr = len([i for i in os.listdir(DIR) if image_type in i]) + 1
        print cntr
        if len(Type)==0:
            f = open(os.path.join(DIR , image_type + "_"+ str(cntr)+".jpg"), 'wb')
        else :
            f = open(os.path.join(DIR , image_type + "_"+ str(cntr)+"."+Type), 'wb')


        f.write(raw_img)
        f.close()
    except Exception as e:
        print "could not load : "+img
        print e
# Out:
# query imageburnt kitchen
# https://www.google.co.in/search?q=burnt+kitchen&source=lnms&tbm=isch
# there are total 100 images
# 1
# 2
# 3
# could not load : https://cleanfax.com/wp-content/uploads/2015/08/Burnt-Kitchen-PNG.png
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# 4
# 5
# 6
# 7
# 8
# could not load : https://previews.123rf.com/images/thomaseder/thomaseder1701/thomaseder170100404/71794467-grid-of-dishwasher-in-burnt-kitchen.jpg
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# 9
# 10
# 11
# 12
# could not load : http://www.real-fix.com/wp-content/uploads/2016/05/SWNS_TUMBLEDRYER_FIRE_08-750x500.jpg
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# 13
# 14
# 15
# 16
# could not load : https://st.hzcdn.com/fimgs/8411a4b0018a6e5b_9558-w312-h312-b0-p0--rustic-kitchen.jpg
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# 17
# 18
# 19
# 20
# 21
# 22
# 23
# could not load : https://www.recipeswithessentialoils.com/wp-content/uploads/2017/04/Clean-Burnt-Baking-Sheets5.jpg
# <urlopen error [Errno 54] Connection reset by peer>
# could not load : https://static.standard.co.uk/s3fs-public/thumbnails/image/2015/09/22/08/Toast1.jpg?w968
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# 24
# 25
# 26
# 27
# 28
# 29
# 30
# could not load : https://uptownalmanac.com/sites/default/files/styles/full-post-width/public/images-on-cdn/502-capp-kitchen.jpg
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# 31
# could not load : https://retrorenovation.com/wp-content/uploads/2017/08/youngstown-kitchen-cabinets-blue-burnt.jpg
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# 32
# 33
# 34
# 35
# could not load : https://media.gettyimages.com/photos/the-burnt-kitchen-of-a-house-hit-by-a-masive-forest-fire-in-the-city-picture-id625711138
# <urlopen error [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:661)>
# 36
# could not load : https://st.hzcdn.com/fimgs/5d8195a804e5e6d4_7748-w312-h312-b0-p0--traditional-kitchen.jpg
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# 37
# 38
# 39
# could not load : https://www.theborneopost.com/newsimages/2012/06/B0620.jpg
# <urlopen error [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:661)>
# 40
# 41
# 42
# could not load : https://hips.hearstapps.com/hbu.h-cdn.co/assets/cm/15/04/54c1529166e37_-_01-hbx-iron-chauvin-lanterns-0514-de.jpg
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# 43
# could not load : https://assets.bonappetit.com/photos/57c5cfd2a184a3c9209db8a4/master/w_1200,c_limit/bradley-cooper-burnt.jpg
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# 44
# 45
# 46
# 47
# could not load : https://media.istockphoto.com/photos/kitchen-of-a-burnt-house-picture-id97470978
# <urlopen error [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:661)>
# 48
# could not load : https://hips.hearstapps.com/hbu.h-cdn.co/assets/cm/15/04/54c1529166e37_-_01-hbx-iron-chauvin-lanterns-0514-de.jpg?crop=0.7493055555555556xw:1xh;center,top&resize=480:*
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# 49
# could not load : https://media.gettyimages.com/photos/burnt-kitchen-picture-id862507620
# <urlopen error [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:661)>
# 50
# 51
# 52
# could not load : https://st.hzcdn.com/fimgs/9bb19cf00fa9522f_0934-w312-h312-b0-p0--shabby-chic-style-kitchen.jpg
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# could not load : https://media.istockphoto.com/photos/kitchen-oven-accidents-with-over-burnt-food-picture-id1030288404
# <urlopen error [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:661)>
# 53
# 54
# 55
# could not load : https://target.scene7.com/is/image/Target/GUEST_7918ec2a-2f65-40dc-8596-19c156bc18f6?wid=488&hei=488&fmt=pjpeg
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# 56
# 57
# 58
# 59
# 60
# 61
# could not load : https://hips.hearstapps.com/del.h-cdn.co/assets/15/43/1024x512/landscape-1445632838-burnt-trailer-bradley-cooper1.jpg?resize=480:*
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# could not load : https://www.thewrap.com/wp-content/uploads/2015/08/bradley-cooper-burnt.jpg
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# could not load : https://secure.img1-fg.wfcdn.com/im/72600909/resize-h310-w310%5Ecompr-r85/5662/56624894/burnt-orange-orange-bath-rug.jpg
# <urlopen error [SSL: TLSV1_ALERT_PROTOCOL_VERSION] tlsv1 alert protocol version (_ssl.c:661)>
# could not load : https://render.fineartamerica.com/images/rendered/default/metal-print/8.000/6.000/break/images-medium-5/man-wearing-party-hat-looking-at-burnt-turkey-in-kitchen-alan-thornton.jpg
# <urlopen error [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:661)>
# 62
# 63
# 64
# 65
# 66
# 67
# 68
# 69
# 70
# 71
# 72
# 73
# 74
# could not load : https://media.gettyimages.com/photos/the-burnt-kitchen-interior-of-a-damaged-house-stands-following-a-at-picture-id1005114786
# <urlopen error [SSL: SSLV3_ALERT_HANDSHAKE_FAILURE] sslv3 alert handshake failure (_ssl.c:661)>
# 75
# could not load : http://tifannyfrench.info/wp-content/uploads/2018/09/burnt-kitchen-table-top-with-high-sets-eugeneerchov.jpg
# <urlopen error [Errno 8] nodename nor servname provided, or not known>

# %%
# %ls
# Out:
# Applications/                  Music/
# DataCleaningTemplate.ipynb     Pictures/
# Desktop/                       Public/
# Documents/                     google_image_collector.ipynb
# Downloads/                     google_image_downloader.ipynb
# Library/                       upwork_test.ipynb
# Movies/
